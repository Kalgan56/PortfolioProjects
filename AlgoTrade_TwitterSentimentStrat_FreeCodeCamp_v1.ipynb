# %% [markdown]
# # Twitter Sentiment Investing strategy
# ## 1. Load Twitter sentiment data
# - Load the twitter sentiment dataset, set the index, calculate the engagement ratio and filter out stocks with no significant twitter activity

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
import os
plt.style.use('ggplot')

sentiment_df=pd.read_csv('sentiment_data.csv')
sentiment_df
# Out:
#              date symbol  twitterPosts  twitterComments  twitterLikes  \
# 0      2021-11-18   AAPL         811.0           2592.0       21674.0
# 1      2021-11-18    ABT          21.0              3.0          13.0
# 2      2021-11-18    AMD         150.0            675.0        2949.0
# 3      2021-11-18   AMZN         557.0           1315.0       12969.0
# 4      2021-11-18   ATVI          82.0             36.0         131.0
# ...           ...    ...           ...              ...           ...
# 27230  2023-01-04    TMO          21.0              2.0          32.0
# 27231  2023-01-04   TSLA        6767.0         540711.0     3810688.0
# 27232  2023-01-04    TSN          35.0            168.0         460.0
# 27233  2023-01-04      V         132.0           1008.0        5943.0
# 27234  2023-01-04    XOM         212.0            374.0        2071.0
#
#        twitterImpressions  twitterSentiment
# 0               7981808.0               NaN
# ...

# %%
# set date to datetime format
sentiment_df['date']=pd.to_datetime(sentiment_df['date'])

sentiment_df=sentiment_df.set_index(['date','symbol'])
sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            ABT             21.0              3.0          13.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
# ...                         ...              ...           ...
# 2023-01-04 TMO             21.0              2.0          32.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN
#            ABT                64089.0               NaN
# ...

# %%
# calculate engagement ratio to try and filter out bot activity
# if ratio of likes to comments is high then probably lots of bots
sentiment_df['engagement_ratio']=sentiment_df['twitterComments']/sentiment_df['twitterLikes']
sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            ABT             21.0              3.0          13.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
# ...                         ...              ...           ...
# 2023-01-04 TMO             21.0              2.0          32.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %%
# filter out stocks with not a lot of comments or likes
sentiment_df_2=sentiment_df[(sentiment_df['twitterLikes']>20)&(sentiment_df['twitterComments']>10)]
sentiment_df_2
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
#            BA              61.0             55.0         342.0
# ...                         ...              ...           ...
# 2023-01-04 T              184.0           3409.0       14271.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %% [markdown]
# ## 2. Aggregate monthly and calculate average sentiment for the month
# - Aggregate on the monthly level and calculate average monthly metric, for the one we choose

# %%
# basically make monthly groups for each symbol and then take the mean of the engagement ratio for the whole month
aggregated_df=(sentiment_df_2.reset_index('symbol').groupby([pd.Grouper(freq='M'),'symbol'])[['engagement_ratio']].mean())

# rank the symbols based on the engagement ratio. high engagement ratio leads to a higher rank, low engagement ratio is a lower rank since it's probably bots
aggregated_df['rank']=(aggregated_df.groupby(level=0)['engagement_ratio'].transform(lambda x: x.rank(ascending=False)))

aggregated_df
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-11-30 AAL             0.203835  37.0
#            AAPL            0.256318  23.0
#            ABBV            0.244677  26.0
#            ABT             0.313368  14.0
#            AES             0.864613   2.0
# ...                             ...   ...
# 2023-01-31 TMO             0.333313  19.0
#            TSLA            0.151992  72.0
#            TSN             0.280553  30.0
#            V               0.194045  60.0
#            XOM             0.217904  53.0
#
# [1109 rows x 2 columns]

# %% [markdown]
# ## 3. Select Top 5 stocks based on their cross-sectional ranking for each month
# - select top 5 stocks by rank for each month and fix the date to start at beginning of next month

# %%
# filtered_df.head(20)filtered_df=aggregated_df[aggregated_df['rank']<6]
# filtered_df=filtered_df.reset_index(level=1)
# filtered_df.index=filtered_df.index+pd.DateOffset(1)
# filtered_df=filtered_df.reset_index().set_index(['date','symbol'])
filtered_df.head(20)
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-12-01 AES             0.864613   2.0
#            FCX             0.626323   5.0
#            MNST            0.699721   3.0
#            OXY             2.147741   1.0
#            SLB             0.647374   4.0
# 2022-01-01 D               0.801994   5.0
#            FCX             0.841220   4.0
#            L               6.507246   1.0
#            LUV             1.303215   2.0
#            MA              0.883401   3.0
# 2022-02-01 AMD             0.715556   4.0
#            D               1.136678   1.0
#            FCX             0.655237   5.0
#            LUV             1.035258   2.0
#            MA              0.729063   3.0
# 2022-03-01 FCX             1.138332   2.0
#            GILD            0.530886   5.0
#            LUV             1.574377   1.0
#            MRO             0.581748   4.0
#            OXY             1.025579   3.0

# %% [markdown]
# ## 4. Extract the stocks to form portfolios with at the start of each new month
# - create a dictionary containing start of month and corresponding selected stocks

# %%
#dates=filtered_df.index.get_level_values('date').unique().tolist()
#fixed_dates={}

for d in dates:
    fixed_dates[d.strftime('%Y-%m-%d')]=filtered_df.xs(d,level=0).index.tolist()

fixed_dates
# Out:
# {'2021-12-01': ['AES', 'FCX', 'MNST', 'OXY', 'SLB'],
#  '2022-01-01': ['D', 'FCX', 'L', 'LUV', 'MA'],
#  '2022-02-01': ['AMD', 'D', 'FCX', 'LUV', 'MA'],
#  '2022-03-01': ['FCX', 'GILD', 'LUV', 'MRO', 'OXY'],
#  '2022-04-01': ['A', 'CRM', 'PFE', 'PM', 'STZ'],
#  '2022-05-01': ['AMD', 'CRM', 'CVX', 'J', 'KEY'],
#  '2022-06-01': ['AMD', 'DD', 'FCX', 'KEY', 'LMT'],
#  '2022-07-01': ['CB', 'CRM', 'DD', 'FCX', 'STZ'],
#  '2022-08-01': ['A', 'DD', 'JPM', 'REGN', 'STZ'],
#  '2022-09-01': ['ABT', 'DIS', 'L', 'META', 'MRNA'],
#  '2022-10-01': ['J', 'KEY', 'L', 'META', 'MU'],
#  '2022-11-01': ['A', 'DD', 'FCX', 'J', 'META'],
#  '2022-12-01': ['AEP', 'AES', 'DD', 'J', 'STZ'],
#  '2023-01-01': ['A', 'AES', 'DAL', 'J', 'KEY'],
#  '2023-02-01': ['A', 'AES', 'BIIB', 'FCX', 'MDT']}

# %% [markdown]
# ## 5. Download fresh stock prices for only select/shortlisted stocks

# %%
stocks_list=sentiment_df_2.index.get_level_values('symbol').unique().tolist()

prices_df=yf.download(tickers=stocks_list,
                      start='2021-01-01',
                      end='2023-03-01')
# Out:
# [**********************66%%******                ]  56 of 85 completedFailed to get ticker 'ATVI' reason: HTTPSConnectionPool(host='fc.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  85 of 85 completed
#
# 1 Failed download:
# ['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %% [markdown]
# ## 6. Calculate portfolio returns with monthly rebalancing

# %%
returns_df=np.log(prices_df['Adj Close']).diff()
returns_df2=returns_df.drop(returns_df.index.values[0])
returns_df2=returns_df2.drop(columns=['ATVI'])
portfolio_df=pd.DataFrame()

for start_date in fixed_dates.keys():
    end_date= (pd.to_datetime(start_date)+pd.offsets.MonthEnd()).strftime('%Y-%m-%d')

    cols=fixed_dates[start_date]
    
    temp_df= returns_df2[start_date:end_date][cols].mean(axis=1).to_frame('portfolio_return') # equally weighted returns
    
    portfolio_df=pd.concat([portfolio_df,temp_df],axis=0)
portfolio_df
# Out:
#             portfolio_return
# Date
# 2021-12-01         -0.016417
# 2021-12-02          0.024872
# 2021-12-03         -0.007711
# 2021-12-06          0.023926
# 2021-12-07          0.030547
# ...                      ...
# 2023-02-22         -0.007870
# 2023-02-23         -0.007323
# 2023-02-24         -0.009463
# 2023-02-27         -0.001871
# 2023-02-28          0.001403
#
# [312 rows x 1 columns]

# %% [markdown]
# ## 7. Download NASDAQ/QQQ prices and calculate returns to compare to our strategy

# %%
qqq_df=yf.download(tickers='QQQ',
                   start='2021-01-08',
                   end='2023-03-01')
qqq_ret=np.log(qqq_df['Adj Close']).diff().to_frame('nasdaq_return')

portfolio_df=portfolio_df.merge(qqq_ret,
                                left_index=True,
                                right_index=True)
portfolio_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             portfolio_return  nasdaq_return
# Date
# 2021-12-01         -0.016417      -0.017159
# 2021-12-02          0.024872       0.007181
# 2021-12-03         -0.007711      -0.017542
# 2021-12-06          0.023926       0.007981
# 2021-12-07          0.030547       0.029669
# ...                      ...            ...
# 2023-02-22         -0.007870       0.000748
# 2023-02-23         -0.007323       0.008696
# 2023-02-24         -0.009463      -0.016886
# 2023-02-27         -0.001871       0.007136
# 2023-02-28          0.001403      -0.001294
#
# [312 rows x 2 columns]

# %%
import matplotlib.ticker as mtick
portfolios_cumulative_return=np.exp(np.log1p(portfolio_df).cumsum().sub(1))

portfolios_cumulative_return.plot(figsize=(16,6))

plt.title('Twitter Engagement Ratio Strategy Return Over Time')

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

plt.ylabel('Return')

plt.show()
